# %% [markdown]
# # AGI-META Phase 4 Control Center
# Use this notebook in Kaggle to run final-evaluation checks and track publish-ready outputs.

# %%
from pathlib import Path
ROOT = Path('/kaggle/working')
phase4 = ROOT / 'agi_meta_phase4'
required = [
    'PHASE4_FINAL_EVAL_RUNBOOK.md',
    'ROBUSTNESS_AUDIT.md',
    'TECHNICAL_REPORT_TEMPLATE.md',
    'WINNING_METHOD_ANALYSIS.md',
]
for name in required:
    p = phase4 / name
    print(f'{name}:', 'OK' if p.exists() else 'MISSING')

# %%
import json
nb_path = phase4 / 'kaggle' / 'phase4_control_center.ipynb'
print('Notebook JSON valid:', json.loads(nb_path.read_text()) is not None)

# %% [markdown]
# ## Finalization checklist
# - [ ] Private scoring complete
# - [ ] Top-20 deterministic rerun complete
# - [ ] Robustness audit complete
# - [ ] Final leaderboard exported
# - [ ] Technical report drafted
